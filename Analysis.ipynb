# %% [markdown]
# Name: Amogh Javali

# %% [markdown]
# ID: NN/22/2355

# %% [markdown]
# Role: Data Analytics

# %%
# !pip3 install pandas numpy
# Out:
# Requirement already satisfied: pandas in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# Data Reading

# %%
df = pd.read_csv("CarPrice_Assignment.csv")

# %% [markdown]
# Inspecting Data

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Checking for null values and Percentage

# %%
df.isnull()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     False      False    False     False       False       False    False
# 1     False      False    False     False       False       False    False
# 2     False      False    False     False       False       False    False
# 3     False      False    False     False       False       False    False
# 4     False      False    False     False       False       False    False
# ..      ...        ...      ...       ...         ...         ...      ...
# 200   False      False    False     False       False       False    False
# 201   False      False    False     False       False       False    False
# 202   False      False    False     False       False       False    False
# 203   False      False    False     False       False       False    False
# 204   False      False    False     False       False       False    False
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0         False           False      False  ...       False       False
# 1         False           False      False  ...       False       False
# 2         False           False      False  ...       False       False
# 3         False           False      False  ...       False       False
# 4         False           False      False  ...       False       False
# ..          ...             ...        ...  ...         ...         ...
# 200       False           False      False  ...       False       False
# 201       False           False      False  ...       False       False
# 202       False           False      False  ...       False       False
# 203       False           False      False  ...       False       False
# 204       False           False      False  ...       False       False
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0        False   False             False       False    False    False
# 1        False   False             False       False    False    False
# 2        False   False             False       False    False    False
# 3        False   False             False       False    False    False
# 4        False   False             False       False    False    False
# ..         ...     ...               ...         ...      ...      ...
# 200      False   False             False       False    False    False
# 201      False   False             False       False    False    False
# 202      False   False             False       False    False    False
# 203      False   False             False       False    False    False
# 204      False   False             False       False    False    False
#
#      highwaympg  price
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ..          ...    ...
# 200       False  False
# 201       False  False
# 202       False  False
# 203       False  False
# 204       False  False
#
# [205 rows x 26 columns]

# %%
null_counts = df.isnull().sum()

# %%
null_counts
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
null_percentage = (df.isnull().sum() / len(df)) * 100

# %%
null_percentage
# Out:
# car_ID              0.0
# symboling           0.0
# CarName             0.0
# fueltype            0.0
# aspiration          0.0
# doornumber          0.0
# carbody             0.0
# drivewheel          0.0
# enginelocation      0.0
# wheelbase           0.0
# carlength           0.0
# carwidth            0.0
# carheight           0.0
# curbweight          0.0
# enginetype          0.0
# cylindernumber      0.0
# enginesize          0.0
# fuelsystem          0.0
# boreratio           0.0
# stroke              0.0
# compressionratio    0.0
# horsepower          0.0
# peakrpm             0.0
# citympg             0.0
# highwaympg          0.0
# price               0.0
# dtype: float64

# %%
null_df = pd.DataFrame({'Null Count': null_counts, 'Null Percentage': null_percentage})

# %%
null_df
# Out:
#                   Null Count  Null Percentage
# car_ID                     0              0.0
# symboling                  0              0.0
# CarName                    0              0.0
# fueltype                   0              0.0
# aspiration                 0              0.0
# doornumber                 0              0.0
# carbody                    0              0.0
# drivewheel                 0              0.0
# enginelocation             0              0.0
# wheelbase                  0              0.0
# carlength                  0              0.0
# carwidth                   0              0.0
# carheight                  0              0.0
# curbweight                 0              0.0
# enginetype                 0              0.0
# cylindernumber             0              0.0
# enginesize                 0              0.0
# fuelsystem                 0              0.0
# boreratio                  0              0.0
# stroke                     0              0.0
# compressionratio           0              0.0
# horsepower                 0              0.0
# peakrpm                    0              0.0
# citympg                    0              0.0
# highwaympg                 0              0.0
# price                      0              0.0

# %%
null_df = null_df[null_df['Null Count'] > 0]

# %%
null_df
# Out:
# Empty DataFrame
# Columns: [Null Count, Null Percentage]
# Index: []

# %%
print(null_df)
# Out:
# Empty DataFrame
# Columns: [Null Count, Null Percentage]
# Index: []

# %%
threshold = 40

# %%
columns_to_drop = null_df[null_df['Null Percentage'] > threshold].index

# %%
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
print(f"Dropped columns: {columns_to_drop}")
# Out:
# Dropped columns: Index([], dtype='object')

# %%
columns_to_drop
# Out:
# Index([], dtype='object')

# %%
df.dropna(thresh=df.shape[1] * 0.5, inplace=True)

# %%
print(df.dropna(thresh=df.shape[1] * 0.5, inplace=True))
# Out:
# None

# %% [markdown]
# Dropping 'enginelocation' Column as all cars engine location is Front only

# %%
df.drop(columns=['enginelocation'], axis=1, inplace=True)

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel  wheelbase  carlength  ...  enginesize  \
# 0          two  convertible        rwd       88.6      168.8  ...         130
# 1          two  convertible        rwd       88.6      168.8  ...         130
# 2          two    hatchback        rwd       94.5      171.2  ...         152
# 3         four        sedan        fwd       99.8      176.6  ...         109
# 4         four        sedan        4wd       99.4      176.6  ...         136
# ..         ...          ...        ...        ...        ...  ...         ...
# 200       four        sedan        rwd      109.1      188.8  ...         141
# 201       four        sedan        rwd      109.1      188.8  ...         141
# 202       four        sedan        rwd      109.1      188.8  ...         173
# 203       four        sedan        rwd      109.1      188.8  ...         145
# 204       four        sedan        rwd      109.1      188.8  ...         141
#
#      fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# 0          mpfi       3.47   2.68              9.0         111    5000
# 1          mpfi       3.47   2.68              9.0         111    5000
# 2          mpfi       2.68   3.47              9.0         154    5000
# 3          mpfi       3.19   3.40             10.0         102    5500
# 4          mpfi       3.19   3.40              8.0         115    5500
# ..          ...        ...    ...              ...         ...     ...
# 200        mpfi       3.78   3.15              9.5         114    5400
# 201        mpfi       3.78   3.15              8.7         160    5300
# 202        mpfi       3.58   2.87              8.8         134    5500
# 203         idi       3.01   3.40             23.0         106    4800
# 204        mpfi       3.78   3.15              9.5         114    5400
#
#      citympg  highwaympg    price
# 0         21          27  13495.0
# 1         21          27  16500.0
# 2         19          26  16500.0
# 3         24          30  13950.0
# 4         18          22  17450.0
# ..       ...         ...      ...
# 200       23          28  16845.0
# 201       19          25  19045.0
# 202       18          23  21485.0
# 203       26          27  22470.0
# 204       19          25  22625.0
#
# [205 rows x 25 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df['doornumber'] = df['doornumber'].map({'two': 2, 'four': 4})

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 7
#       4 df['doornumber'] = df['doornumber'].map({'two': 2, 'four': 4})
#       6 plt.figure(figsize=(10,6))
# ----> 7 sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
#       8 plt.title("Feature Correlation Heatmap")
#       9 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'alfa-romero giulia'

# %%
print(df.dtypes)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Dropping Column 'doornumber' because we can see corelation between 'price' and 'doornumber' is '0.032' which is very low.

# %%
df.drop(columns=['doornumber'], axis=1, inplace=True)

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#          carbody drivewheel  wheelbase  carlength  carwidth  ...  enginesize  \
# 0    convertible        rwd       88.6      168.8      64.1  ...         130
# 1    convertible        rwd       88.6      168.8      64.1  ...         130
# 2      hatchback        rwd       94.5      171.2      65.5  ...         152
# 3          sedan        fwd       99.8      176.6      66.2  ...         109
# 4          sedan        4wd       99.4      176.6      66.4  ...         136
# ..           ...        ...        ...        ...       ...  ...         ...
# 200        sedan        rwd      109.1      188.8      68.9  ...         141
# 201        sedan        rwd      109.1      188.8      68.8  ...         141
# 202        sedan        rwd      109.1      188.8      68.9  ...         173
# 203        sedan        rwd      109.1      188.8      68.9  ...         145
# 204        sedan        rwd      109.1      188.8      68.9  ...         141
#
#      fuelsystem boreratio stroke  compressionratio horsepower  peakrpm  \
# 0          mpfi      3.47   2.68               9.0        111     5000
# 1          mpfi      3.47   2.68               9.0        111     5000
# 2          mpfi      2.68   3.47               9.0        154     5000
# 3          mpfi      3.19   3.40              10.0        102     5500
# 4          mpfi      3.19   3.40               8.0        115     5500
# ..          ...       ...    ...               ...        ...      ...
# 200        mpfi      3.78   3.15               9.5        114     5400
# 201        mpfi      3.78   3.15               8.7        160     5300
# 202        mpfi      3.58   2.87               8.8        134     5500
# 203         idi      3.01   3.40              23.0        106     4800
# 204        mpfi      3.78   3.15               9.5        114     5400
#
#      citympg  highwaympg    price
# 0         21          27  13495.0
# 1         21          27  16500.0
# 2         19          26  16500.0
# 3         24          30  13950.0
# 4         18          22  17450.0
# ..       ...         ...      ...
# 200       23          28  16845.0
# 201       19          25  19045.0
# 202       18          23  21485.0
# 203       26          27  22470.0
# 204       19          25  22625.0
#
# [205 rows x 24 columns]

# %%
print(df['fueltype'].unique())
# Out:
# ['gas' 'diesel']

# %% [markdown]
# converting char 'gas' and 'diesel' into numeric '0' and '1' to check correlation

# %%
df['fueltype'] = df['fueltype'].map({'gas': 0, 'diesel': 1})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Dropping 'fueltype' as it is not useful

# %%
df.drop(columns=['fueltype'], axis=1, inplace=True)

# %%
df
# Out:
#      car_ID  symboling                   CarName aspiration      carbody  \
# 0         1          3        alfa-romero giulia        std  convertible
# 1         2          3       alfa-romero stelvio        std  convertible
# 2         3          1  alfa-romero Quadrifoglio        std    hatchback
# 3         4          2               audi 100 ls        std        sedan
# 4         5          2                audi 100ls        std        sedan
# ..      ...        ...                       ...        ...          ...
# 200     201         -1           volvo 145e (sw)        std        sedan
# 201     202         -1               volvo 144ea      turbo        sedan
# 202     203         -1               volvo 244dl        std        sedan
# 203     204         -1                 volvo 246      turbo        sedan
# 204     205         -1               volvo 264gl      turbo        sedan
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  ...  enginesize  \
# 0          rwd       88.6      168.8      64.1       48.8  ...         130
# 1          rwd       88.6      168.8      64.1       48.8  ...         130
# 2          rwd       94.5      171.2      65.5       52.4  ...         152
# 3          fwd       99.8      176.6      66.2       54.3  ...         109
# 4          4wd       99.4      176.6      66.4       54.3  ...         136
# ..         ...        ...        ...       ...        ...  ...         ...
# 200        rwd      109.1      188.8      68.9       55.5  ...         141
# 201        rwd      109.1      188.8      68.8       55.5  ...         141
# 202        rwd      109.1      188.8      68.9       55.5  ...         173
# 203        rwd      109.1      188.8      68.9       55.5  ...         145
# 204        rwd      109.1      188.8      68.9       55.5  ...         141
#
#     fuelsystem boreratio  stroke compressionratio  horsepower  peakrpm  \
# 0         mpfi      3.47    2.68              9.0         111     5000
# 1         mpfi      3.47    2.68              9.0         111     5000
# 2         mpfi      2.68    3.47              9.0         154     5000
# 3         mpfi      3.19    3.40             10.0         102     5500
# 4         mpfi      3.19    3.40              8.0         115     5500
# ..         ...       ...     ...              ...         ...      ...
# 200       mpfi      3.78    3.15              9.5         114     5400
# 201       mpfi      3.78    3.15              8.7         160     5300
# 202       mpfi      3.58    2.87              8.8         134     5500
# 203        idi      3.01    3.40             23.0         106     4800
# 204       mpfi      3.78    3.15              9.5         114     5400
#
#      citympg  highwaympg    price
# 0         21          27  13495.0
# 1         21          27  16500.0
# 2         19          26  16500.0
# 3         24          30  13950.0
# 4         18          22  17450.0
# ..       ...         ...      ...
# 200       23          28  16845.0
# 201       19          25  19045.0
# 202       18          23  21485.0
# 203       26          27  22470.0
# 204       19          25  22625.0
#
# [205 rows x 23 columns]

# %%
print(df['aspiration'].unique())
# Out:
# ['std' 'turbo']

# %%
df['aspiration']=df['aspiration'].map({'std':0,'turbo':1})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Dropping 'aspiration' column

# %%
df.drop(columns=['aspiration'],axis=1,inplace=True)

# %% [markdown]
# Removing 'stroke' column

# %%
df.drop(columns=['stroke'],axis=1,inplace=True)

# %% [markdown]
# Sorting the table by 'price'(Ascending order)

# %%
df.sort_values(by='price', ascending=True, inplace=True)

# %%
df['price'].head()
# Out:
# 138    5118.0
# 18     5151.0
# 50     5195.0
# 150    5348.0
# 76     5389.0
# Name: price, dtype: float64

# %%
df
# Out:
#      car_ID  symboling                          CarName      carbody  \
# 138     139          2                           subaru    hatchback
# 18       19          2                 chevrolet impala    hatchback
# 50       51          1                        maxda rx3    hatchback
# 150     151          1            toyota corona mark ii    hatchback
# 76       77          2                mitsubishi mirage    hatchback
# ..      ...        ...                              ...          ...
# 17       18          0                           bmw x3        sedan
# 128     129          3                   porsche boxter  convertible
# 73       74          0            buick century special        sedan
# 16       17          0                           bmw x5        sedan
# 74       75          1  buick regal sport coupe (turbo)      hardtop
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  curbweight  ...  \
# 138        fwd       93.7      156.9      63.4       53.7        2050  ...
# 18         fwd       88.4      141.1      60.3       53.2        1488  ...
# 50         fwd       93.1      159.1      64.2       54.1        1890  ...
# 150        fwd       95.7      158.7      63.6       54.5        1985  ...
# 76         fwd       93.7      157.3      64.4       50.8        1918  ...
# ..         ...        ...        ...       ...        ...         ...  ...
# 17         rwd      110.0      197.0      70.9       56.3        3505  ...
# 128        rwd       89.5      168.9      65.0       51.6        2800  ...
# 73         rwd      120.9      208.1      71.7       56.7        3900  ...
# 16         rwd      103.5      193.8      67.9       53.7        3380  ...
# 74         rwd      112.0      199.2      72.0       55.4        3715  ...
#
#     cylindernumber enginesize  fuelsystem boreratio  compressionratio  \
# 138           four         97        2bbl      3.62               9.0
# 18           three         61        2bbl      2.91               9.5
# 50            four         91        2bbl      3.03               9.0
# 150           four         92        2bbl      3.05               9.0
# 76            four         92        2bbl      2.97               9.4
# ..             ...        ...         ...       ...               ...
# 17             six        209        mpfi      3.62               8.0
# 128            six        194        mpfi      3.74               9.5
# 73           eight        308        mpfi      3.80               8.0
# 16             six        209        mpfi      3.62               8.0
# 74           eight        304        mpfi      3.80               8.0
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 138          69     4900       31          36   5118.0
# 18           48     5100       47          53   5151.0
# 50           68     5000       30          31   5195.0
# 150          62     4800       35          39   5348.0
# 76           68     5500       37          41   5389.0
# ..          ...      ...      ...         ...      ...
# 17          182     5400       15          20  36880.0
# 128         207     5900       17          25  37028.0
# 73          184     4500       14          16  40960.0
# 16          182     5400       16          22  41315.0
# 74          184     4500       14          16  45400.0
#
# [205 rows x 21 columns]

# %% [markdown]
# Data Visualization

# %% [markdown]
# Pairplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
selected_features = ['price', 'horsepower', 'curbweight', 'citympg', 'enginesize']
sns.pairplot(df[selected_features], diag_kind='kde')
plt.show()

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
df
# Out:
#      car_ID  symboling                          CarName      carbody  \
# 138     139          2                           subaru    hatchback
# 18       19          2                 chevrolet impala    hatchback
# 50       51          1                        maxda rx3    hatchback
# 150     151          1            toyota corona mark ii    hatchback
# 76       77          2                mitsubishi mirage    hatchback
# ..      ...        ...                              ...          ...
# 17       18          0                           bmw x3        sedan
# 128     129          3                   porsche boxter  convertible
# 73       74          0            buick century special        sedan
# 16       17          0                           bmw x5        sedan
# 74       75          1  buick regal sport coupe (turbo)      hardtop
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  curbweight  ...  \
# 138        fwd       93.7      156.9      63.4       53.7        2050  ...
# 18         fwd       88.4      141.1      60.3       53.2        1488  ...
# 50         fwd       93.1      159.1      64.2       54.1        1890  ...
# 150        fwd       95.7      158.7      63.6       54.5        1985  ...
# 76         fwd       93.7      157.3      64.4       50.8        1918  ...
# ..         ...        ...        ...       ...        ...         ...  ...
# 17         rwd      110.0      197.0      70.9       56.3        3505  ...
# 128        rwd       89.5      168.9      65.0       51.6        2800  ...
# 73         rwd      120.9      208.1      71.7       56.7        3900  ...
# 16         rwd      103.5      193.8      67.9       53.7        3380  ...
# 74         rwd      112.0      199.2      72.0       55.4        3715  ...
#
#     cylindernumber enginesize  fuelsystem boreratio  compressionratio  \
# 138           four         97        2bbl      3.62               9.0
# 18           three         61        2bbl      2.91               9.5
# 50            four         91        2bbl      3.03               9.0
# 150           four         92        2bbl      3.05               9.0
# 76            four         92        2bbl      2.97               9.4
# ..             ...        ...         ...       ...               ...
# 17             six        209        mpfi      3.62               8.0
# 128            six        194        mpfi      3.74               9.5
# 73           eight        308        mpfi      3.80               8.0
# 16             six        209        mpfi      3.62               8.0
# 74           eight        304        mpfi      3.80               8.0
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 138          69     4900       31          36   5118.0
# 18           48     5100       47          53   5151.0
# 50           68     5000       30          31   5195.0
# 150          62     4800       35          39   5348.0
# 76           68     5500       37          41   5389.0
# ..          ...      ...      ...         ...      ...
# 17          182     5400       15          20  36880.0
# 128         207     5900       17          25  37028.0
# 73          184     4500       14          16  40960.0
# 16          182     5400       16          22  41315.0
# 74          184     4500       14          16  45400.0
#
# [205 rows x 21 columns]

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
# C:\Users\amogh\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\extensions\storemagic.py:229: UserWarning: This is now an optional IPython functionality, setting autorestore/df requires you to install the `pickleshare` library.
#   db[ 'autorestore/' + arg ] = obj

# %%
# !pip install pickleshare
# Out:
# Requirement already satisfied: pickleshare in c:\users\amogh\appdata\local\programs\python\python312\lib\site-packages (0.7.5)
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %%
df.to_csv("updated_df.csv",index=False)

# %%
import pandas as pd
df = pd.read_csv("updated_df.csv")

# %%
df
# Out:
#      car_ID  symboling                          CarName      carbody  \
# 0       139          2                           subaru    hatchback
# 1        19          2                 chevrolet impala    hatchback
# 2        51          1                        maxda rx3    hatchback
# 3       151          1            toyota corona mark ii    hatchback
# 4        77          2                mitsubishi mirage    hatchback
# ..      ...        ...                              ...          ...
# 200      18          0                           bmw x3        sedan
# 201     129          3                   porsche boxter  convertible
# 202      74          0            buick century special        sedan
# 203      17          0                           bmw x5        sedan
# 204      75          1  buick regal sport coupe (turbo)      hardtop
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  curbweight  ...  \
# 0          fwd       93.7      156.9      63.4       53.7        2050  ...
# 1          fwd       88.4      141.1      60.3       53.2        1488  ...
# 2          fwd       93.1      159.1      64.2       54.1        1890  ...
# 3          fwd       95.7      158.7      63.6       54.5        1985  ...
# 4          fwd       93.7      157.3      64.4       50.8        1918  ...
# ..         ...        ...        ...       ...        ...         ...  ...
# 200        rwd      110.0      197.0      70.9       56.3        3505  ...
# 201        rwd       89.5      168.9      65.0       51.6        2800  ...
# 202        rwd      120.9      208.1      71.7       56.7        3900  ...
# 203        rwd      103.5      193.8      67.9       53.7        3380  ...
# 204        rwd      112.0      199.2      72.0       55.4        3715  ...
#
#     cylindernumber enginesize  fuelsystem boreratio  compressionratio  \
# 0             four         97        2bbl      3.62               9.0
# 1            three         61        2bbl      2.91               9.5
# 2             four         91        2bbl      3.03               9.0
# 3             four         92        2bbl      3.05               9.0
# 4             four         92        2bbl      2.97               9.4
# ..             ...        ...         ...       ...               ...
# 200            six        209        mpfi      3.62               8.0
# 201            six        194        mpfi      3.74               9.5
# 202          eight        308        mpfi      3.80               8.0
# 203            six        209        mpfi      3.62               8.0
# 204          eight        304        mpfi      3.80               8.0
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 0            69     4900       31          36   5118.0
# 1            48     5100       47          53   5151.0
# 2            68     5000       30          31   5195.0
# 3            62     4800       35          39   5348.0
# 4            68     5500       37          41   5389.0
# ..          ...      ...      ...         ...      ...
# 200         182     5400       15          20  36880.0
# 201         207     5900       17          25  37028.0
# 202         184     4500       14          16  40960.0
# 203         182     5400       16          22  41315.0
# 204         184     4500       14          16  45400.0
#
# [205 rows x 21 columns]

# %%
df.to_csv("updated_df.csv",index=False)

# %%
df
# Out:
#      car_ID  symboling                          CarName      carbody  \
# 0       139          2                           subaru    hatchback
# 1        19          2                 chevrolet impala    hatchback
# 2        51          1                        maxda rx3    hatchback
# 3       151          1            toyota corona mark ii    hatchback
# 4        77          2                mitsubishi mirage    hatchback
# ..      ...        ...                              ...          ...
# 200      18          0                           bmw x3        sedan
# 201     129          3                   porsche boxter  convertible
# 202      74          0            buick century special        sedan
# 203      17          0                           bmw x5        sedan
# 204      75          1  buick regal sport coupe (turbo)      hardtop
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  curbweight  ...  \
# 0          fwd       93.7      156.9      63.4       53.7        2050  ...
# 1          fwd       88.4      141.1      60.3       53.2        1488  ...
# 2          fwd       93.1      159.1      64.2       54.1        1890  ...
# 3          fwd       95.7      158.7      63.6       54.5        1985  ...
# 4          fwd       93.7      157.3      64.4       50.8        1918  ...
# ..         ...        ...        ...       ...        ...         ...  ...
# 200        rwd      110.0      197.0      70.9       56.3        3505  ...
# 201        rwd       89.5      168.9      65.0       51.6        2800  ...
# 202        rwd      120.9      208.1      71.7       56.7        3900  ...
# 203        rwd      103.5      193.8      67.9       53.7        3380  ...
# 204        rwd      112.0      199.2      72.0       55.4        3715  ...
#
#     cylindernumber enginesize  fuelsystem boreratio  compressionratio  \
# 0             four         97        2bbl      3.62               9.0
# 1            three         61        2bbl      2.91               9.5
# 2             four         91        2bbl      3.03               9.0
# 3             four         92        2bbl      3.05               9.0
# 4             four         92        2bbl      2.97               9.4
# ..             ...        ...         ...       ...               ...
# 200            six        209        mpfi      3.62               8.0
# 201            six        194        mpfi      3.74               9.5
# 202          eight        308        mpfi      3.80               8.0
# 203            six        209        mpfi      3.62               8.0
# 204          eight        304        mpfi      3.80               8.0
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 0            69     4900       31          36   5118.0
# 1            48     5100       47          53   5151.0
# 2            68     5000       30          31   5195.0
# 3            62     4800       35          39   5348.0
# 4            68     5500       37          41   5389.0
# ..          ...      ...      ...         ...      ...
# 200         182     5400       15          20  36880.0
# 201         207     5900       17          25  37028.0
# 202         184     4500       14          16  40960.0
# 203         182     5400       16          22  41315.0
# 204         184     4500       14          16  45400.0
#
# [205 rows x 21 columns]

# %% [markdown]
# Data Preperation

# %%
df['carCompany'] = df['CarName'].apply(lambda x: x.split(' ')[0].lower())

# %%
df['carCompany']
# Out:
# 0          subaru
# 1       chevrolet
# 2           maxda
# 3          toyota
# 4      mitsubishi
#           ...
# 200           bmw
# 201       porsche
# 202         buick
# 203           bmw
# 204         buick
# Name: carCompany, Length: 205, dtype: object

# %%
print(df['carCompany'].unique())
# Out:
# ['subaru' 'chevrolet' 'maxda' 'toyota' 'mitsubishi' 'honda' 'nissan'
#  'plymouth' 'dodge' 'mazda' 'isuzu' 'vokswagen' 'volkswagen' 'renault'
#  'vw' 'saab' 'peugeot' 'volvo' 'alfa-romero' 'audi' 'toyouta' 'bmw'
#  'mercury' 'porsche' 'buick' 'jaguar' 'porcshce']

# %%
df['carCompany']=df['carCompany'].replace({
    'maxda': 'mazda',         
    'vokswagen': 'volkswagen', 
    'vw': 'volkswagen',        
    'toyouta': 'toyota',      
    'porcshce': 'porsche',     
    'alfa-romero': 'alfa-romeo'
})

# %%
df['carCompany'].unique()
# Out:
# array(['subaru', 'chevrolet', 'mazda', 'toyota', 'mitsubishi', 'honda',
#        'nissan', 'plymouth', 'dodge', 'isuzu', 'volkswagen', 'renault',
#        'saab', 'peugeot', 'volvo', 'alfa-romeo', 'audi', 'bmw', 'mercury',
#        'porsche', 'buick', 'jaguar'], dtype=object)

# %% [markdown]
# Dropping 'car_ID' column

# %%
df.drop(columns=['car_ID'], axis=1, inplace=True)

# %%
df = pd.get_dummies(df, columns=['carCompany', 'enginetype', 'carbody'], drop_first=True)

# %%
df
# Out:
#      symboling                          CarName drivewheel  wheelbase  \
# 0            2                           subaru        fwd       93.7
# 1            2                 chevrolet impala        fwd       88.4
# 2            1                        maxda rx3        fwd       93.1
# 3            1            toyota corona mark ii        fwd       95.7
# 4            2                mitsubishi mirage        fwd       93.7
# ..         ...                              ...        ...        ...
# 200          0                           bmw x3        rwd      110.0
# 201          3                   porsche boxter        rwd       89.5
# 202          0            buick century special        rwd      120.9
# 203          0                           bmw x5        rwd      103.5
# 204          1  buick regal sport coupe (turbo)        rwd      112.0
#
#      carlength  carwidth  carheight  curbweight cylindernumber  enginesize  \
# 0        156.9      63.4       53.7        2050           four          97
# 1        141.1      60.3       53.2        1488          three          61
# 2        159.1      64.2       54.1        1890           four          91
# 3        158.7      63.6       54.5        1985           four          92
# 4        157.3      64.4       50.8        1918           four          92
# ..         ...       ...        ...         ...            ...         ...
# 200      197.0      70.9       56.3        3505            six         209
# 201      168.9      65.0       51.6        2800            six         194
# 202      208.1      71.7       56.7        3900          eight         308
# 203      193.8      67.9       53.7        3380            six         209
# 204      199.2      72.0       55.4        3715          eight         304
#
#      ... enginetype_dohcv  enginetype_l  enginetype_ohc  enginetype_ohcf  \
# 0    ...            False         False           False             True
# 1    ...            False          True           False            False
# 2    ...            False         False            True            False
# 3    ...            False         False            True            False
# 4    ...            False         False            True            False
# ..   ...              ...           ...             ...              ...
# 200  ...            False         False            True            False
# 201  ...            False         False           False             True
# 202  ...            False         False           False            False
# 203  ...            False         False            True            False
# 204  ...            False         False           False            False
#
#      enginetype_ohcv  enginetype_rotor  carbody_hardtop  carbody_hatchback  \
# 0              False             False            False               True
# 1              False             False            False               True
# 2              False             False            False               True
# 3              False             False            False               True
# 4              False             False            False               True
# ..               ...               ...              ...                ...
# 200            False             False            False              False
# 201            False             False            False              False
# 202             True             False            False              False
# 203            False             False            False              False
# 204             True             False             True              False
#
#      carbody_sedan  carbody_wagon
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
# ..             ...            ...
# 200           True          False
# 201          False          False
# 202           True          False
# 203           True          False
# 204          False          False
#
# [205 rows x 49 columns]

# %%
df.to_csv("updated_df.csv",index=False)

# %%
df.rename(columns={
    'carCompany_subaru': 'is_subaru',
    'carCompany_chevrolet': 'is_chevrolet',
    'carCompany_mazda': 'is_mazda',
    'carCompany_toyota': 'is_toyota',
    'carCompany_mitsubishi': 'is_mitsubishi',
    'carCompany_honda': 'is_honda',
    'carCompany_nissan': 'is_nissan',
    'carCompany_plymouth': 'is_plymouth',
    'carCompany_dodge': 'is_dodge',
    'carCompany_isuzu': 'is_isuzu',
    'carCompany_volkswagen': 'is_volkswagen',
    'carCompany_renault': 'is_renault',
    'carCompany_saab': 'is_saab',
    'carCompany_peugeot': 'is_peugeot',
    'carCompany_volvo': 'is_volvo',
    'carCompany_alfa-romeo': 'is_alfa_romeo',
    'carCompany_audi': 'is_audi',
    'carCompany_bmw': 'is_bmw',
    'carCompany_mercury': 'is_mercury',
    'carCompany_porsche': 'is_porsche',
    'carCompany_buick': 'is_buick',
    'carCompany_jaguar': 'is_jaguar'
}, inplace=True)

# %%
df.rename(columns={
    'enginetype_dohcv': 'is_dohcv',
    'enginetype_I': 'is_inline',
    'enginetype_ohc': 'is_ohc',
    'enginetype_ohcf': 'is_ohcf',
    'enginetype_ohcv': 'is_ohcv',
    'enginetype_rotor': 'is_rotor'
}, inplace=True)

# %%
df.rename(columns={
    'carbody_hardtop': 'is_hardtop',
    'carbody_sedan': 'is_sedan',
    'carbody_hatchback': 'is_hatchback',
    'carbody_wagon': 'is_wagon'
}, inplace=True)

# %%
df
# Out:
#      symboling                          CarName drivewheel  wheelbase  \
# 0            2                           subaru        fwd       93.7
# 1            2                 chevrolet impala        fwd       88.4
# 2            1                        maxda rx3        fwd       93.1
# 3            1            toyota corona mark ii        fwd       95.7
# 4            2                mitsubishi mirage        fwd       93.7
# ..         ...                              ...        ...        ...
# 200          0                           bmw x3        rwd      110.0
# 201          3                   porsche boxter        rwd       89.5
# 202          0            buick century special        rwd      120.9
# 203          0                           bmw x5        rwd      103.5
# 204          1  buick regal sport coupe (turbo)        rwd      112.0
#
#      carlength  carwidth  carheight  curbweight cylindernumber  enginesize  \
# 0        156.9      63.4       53.7        2050           four          97
# 1        141.1      60.3       53.2        1488          three          61
# 2        159.1      64.2       54.1        1890           four          91
# 3        158.7      63.6       54.5        1985           four          92
# 4        157.3      64.4       50.8        1918           four          92
# ..         ...       ...        ...         ...            ...         ...
# 200      197.0      70.9       56.3        3505            six         209
# 201      168.9      65.0       51.6        2800            six         194
# 202      208.1      71.7       56.7        3900          eight         308
# 203      193.8      67.9       53.7        3380            six         209
# 204      199.2      72.0       55.4        3715          eight         304
#
#      ... is_dohcv  enginetype_l  is_ohc  is_ohcf  is_ohcv  is_rotor  \
# 0    ...    False         False   False     True    False     False
# 1    ...    False          True   False    False    False     False
# 2    ...    False         False    True    False    False     False
# 3    ...    False         False    True    False    False     False
# 4    ...    False         False    True    False    False     False
# ..   ...      ...           ...     ...      ...      ...       ...
# 200  ...    False         False    True    False    False     False
# 201  ...    False         False   False     True    False     False
# 202  ...    False         False   False    False     True     False
# 203  ...    False         False    True    False    False     False
# 204  ...    False         False   False    False     True     False
#
#      is_hardtop  is_hatchback  is_sedan  is_wagon
# 0         False          True     False     False
# 1         False          True     False     False
# 2         False          True     False     False
# 3         False          True     False     False
# 4         False          True     False     False
# ..          ...           ...       ...       ...
# 200       False         False      True     False
# 201       False         False     False     False
# 202       False         False      True     False
# 203       False         False      True     False
# 204        True         False     False     False
#
# [205 rows x 49 columns]

# %%
df.to_csv("updated_df.csv",index=False)

# %%
df['car_stability'] = df['wheelbase'] / df['carlength']

# %%
df['car_stability']
# Out:
# 0      0.597196
# 1      0.626506
# 2      0.585167
# 3      0.603025
# 4      0.595677
#          ...
# 200    0.558376
# 201    0.529899
# 202    0.580971
# 203    0.534056
# 204    0.562249
# Name: car_stability, Length: 205, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_numeric = df.select_dtypes(include=['number']) 

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df[['wheelbase', 'carlength', 'car_stability', 'price']].corr()

print(correlation_matrix)
# Out:
#                wheelbase  carlength  car_stability     price
# wheelbase       1.000000   0.874587      -0.058602  0.577816
# carlength       0.874587   1.000000      -0.533972  0.682920
# car_stability  -0.058602  -0.533972       1.000000 -0.389469
# price           0.577816   0.682920      -0.389469  1.000000

# %% [markdown]
# Dropping 'wheelbase' because 'carlength' is more strongly correlated with 'price' than 'wheelbase'

# %%
df.drop(columns=['wheelbase'], inplace=True)

# %% [markdown]
# Dropping Highly Correlated Features to Avoid Redundancy

# %% [markdown]
# Dropping 'carwidth' and 'curbweight'  as we already dropped 'wheelbase'

# %%
df.drop(columns=['carwidth', 'curbweight'], inplace=True)

# %% [markdown]
# Dropping 'highwaympg'

# %%
df.drop(columns=['highwaympg'], inplace=True)

# %% [markdown]
# Dropping 'car_stability' to avoid redundancy

# %%
df.drop(columns=['car_stability'], inplace=True)

# %%
df.to_csv('updated_df.csv',index=False)

# %% [markdown]
# Data Analysis

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(12, 8), bins=20, edgecolor='black')
plt.suptitle("Feature Distributions", fontsize=14)
plt.tight_layout() 
plt.show()

# %%
brand_columns = [col for col in df.columns if col.startswith('is_')]
print(brand_columns)
# Out:
# ['is_audi', 'is_bmw', 'is_buick', 'is_chevrolet', 'is_dodge', 'is_honda', 'is_isuzu', 'is_jaguar', 'is_mazda', 'is_mercury', 'is_mitsubishi', 'is_nissan', 'is_peugeot', 'is_plymouth', 'is_porsche', 'is_renault', 'is_saab', 'is_subaru', 'is_toyota', 'is_volkswagen', 'is_volvo', 'is_dohcv', 'is_ohc', 'is_ohcf', 'is_ohcv', 'is_rotor', 'is_hardtop', 'is_hatchback', 'is_sedan', 'is_wagon']

# %%
df['carCompany'] = df[brand_columns].idxmax(axis=1).str.replace("is_", "")

# %%
print(df[['carCompany']].head())
# Out:
#    carCompany
# 0      subaru
# 1   chevrolet
# 2       mazda
# 3      toyota
# 4  mitsubishi

# %%
df
# Out:
#      symboling                          CarName drivewheel  carlength  \
# 0            2                           subaru        fwd      156.9
# 1            2                 chevrolet impala        fwd      141.1
# 2            1                        maxda rx3        fwd      159.1
# 3            1            toyota corona mark ii        fwd      158.7
# 4            2                mitsubishi mirage        fwd      157.3
# ..         ...                              ...        ...        ...
# 200          0                           bmw x3        rwd      197.0
# 201          3                   porsche boxter        rwd      168.9
# 202          0            buick century special        rwd      208.1
# 203          0                           bmw x5        rwd      193.8
# 204          1  buick regal sport coupe (turbo)        rwd      199.2
#
#      carheight cylindernumber  enginesize fuelsystem  boreratio  \
# 0         53.7           four          97       2bbl       3.62
# 1         53.2          three          61       2bbl       2.91
# 2         54.1           four          91       2bbl       3.03
# 3         54.5           four          92       2bbl       3.05
# 4         50.8           four          92       2bbl       2.97
# ..         ...            ...         ...        ...        ...
# 200       56.3            six         209       mpfi       3.62
# 201       51.6            six         194       mpfi       3.74
# 202       56.7          eight         308       mpfi       3.80
# 203       53.7            six         209       mpfi       3.62
# 204       55.4          eight         304       mpfi       3.80
#
#      compressionratio  ...  enginetype_l  is_ohc  is_ohcf  is_ohcv  is_rotor  \
# 0                 9.0  ...         False   False     True    False     False
# 1                 9.5  ...          True   False    False    False     False
# 2                 9.0  ...         False    True    False    False     False
# 3                 9.0  ...         False    True    False    False     False
# 4                 9.4  ...         False    True    False    False     False
# ..                ...  ...           ...     ...      ...      ...       ...
# 200               8.0  ...         False    True    False    False     False
# 201               9.5  ...         False   False     True    False     False
# 202               8.0  ...         False   False    False     True     False
# 203               8.0  ...         False    True    False    False     False
# 204               8.0  ...         False   False    False     True     False
#
#      is_hardtop  is_hatchback  is_sedan  is_wagon  carCompany
# 0         False          True     False     False      subaru
# 1         False          True     False     False   chevrolet
# 2         False          True     False     False       mazda
# 3         False          True     False     False      toyota
# 4         False          True     False     False  mitsubishi
# ..          ...           ...       ...       ...         ...
# 200       False         False      True     False         bmw
# 201       False         False     False     False     porsche
# 202       False         False      True     False       buick
# 203       False         False      True     False         bmw
# 204        True         False     False     False       buick
#
# [205 rows x 46 columns]

# %%
df.to_csv("updated_df.csv",index=False)

# %%
df = df.rename(columns={'enginetype_l': 'is_inline'})

# %%
brand_columns = [col for col in df.columns if col.startswith('is_') and col not in ['is_dohcv', 'is_inline', 'is_ohc', 'is_ohcf', 'is_ohcv', 'is_rotor', 'is_hardtop', 'is_sedan', 'is_hatchback', 'is_wagon']]
print("Car Brand Columns:", brand_columns)
# Out:
# Car Brand Columns: ['is_audi', 'is_bmw', 'is_buick', 'is_chevrolet', 'is_dodge', 'is_honda', 'is_isuzu', 'is_jaguar', 'is_mazda', 'is_mercury', 'is_mitsubishi', 'is_nissan', 'is_peugeot', 'is_plymouth', 'is_porsche', 'is_renault', 'is_saab', 'is_subaru', 'is_toyota', 'is_volkswagen', 'is_volvo']

# %%
df['carCompany'] = df[brand_columns].idxmax(axis=1).str.replace("is_", "")

# %%
print(df[['carCompany', 'is_dohcv', 'is_sedan']].head())
# Out:
#    carCompany  is_dohcv  is_sedan
# 0      subaru     False     False
# 1   chevrolet     False     False
# 2       mazda     False     False
# 3      toyota     False     False
# 4  mitsubishi     False     False

# %%
df.to_csv("updated_df.csv",index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.countplot(x=df['carCompany'], order=df['carCompany'].value_counts().index, palette="viridis")
plt.xticks(rotation=90)
plt.title("Car Brand Distribution")
plt.show()
# Out:
# C:\Users\amogh\AppData\Local\Temp\ipykernel_3952\2154864462.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['carCompany'], order=df['carCompany'].value_counts().index, palette="viridis")

# %%
carbody_columns = [col for col in df.columns if col.startswith('is_') and col in ['is_hardtop', 'is_sedan', 'is_hatchback', 'is_wagon']]
print("Car Body Columns:", carbody_columns)
# Out:
# Car Body Columns: ['is_hardtop', 'is_hatchback', 'is_sedan', 'is_wagon']

# %%
df['carbody'] = df[carbody_columns].idxmax(axis=1).str.replace("is_", "")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.barplot(x=df['carbody'], y=df['price'], estimator=sum, palette="coolwarm")
plt.title("Total Price Distribution by Car Body Style")
plt.show()
# Out:
# C:\Users\amogh\AppData\Local\Temp\ipykernel_3952\227401964.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['carbody'], y=df['price'], estimator=sum, palette="coolwarm")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_numeric = df.select_dtypes(include=['number']) 

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['enginesize'], y=df['price'], hue=df['horsepower'], palette="coolwarm")
plt.title("Engine Size vs Price (Gradient by Horsepower)")
plt.show()

# %%
df.to_csv("updated_df.csv",index=False)

# %% [markdown]
# Insight

# %% [markdown]
# From the above graphical representation, based on the Bar Chart, my insight is that 'Toyota' is the most sold car brand, while 'Mercury' is the least sold

# %% [markdown]
# Based on the 'carbody' vs. 'price' analysis, my insight is that sedan and hatchback cars are sold more frequently than wagons and hardtops

# %% [markdown]
# From the heatmap analysis, it's clear that engine size and horsepower are closely linked to higher car prices, meaning bigger and more powerful cars tend to cost more. On the other hand, fuel-efficient cars (higher MPG) are generally priced lower, showing a trade-off between performance and efficiency

# %% [markdown]
# From the scatter plot, we can see that cars with larger engine sizes generally have higher prices. Additionally, the gradient indicates that cars with higher horsepower also tend to be more expensive, suggesting that both engine size and power significantly impact a car's value

# %% [markdown]
# Key Insights

# %% [markdown]
# Most sold car brand: Toyota

# %% [markdown]
# Least sold car brand: Mercury

# %% [markdown]
# Most sold car body type: Sedan

# %% [markdown]
# Least sold car body type: Hardtop

# %% [markdown]
# Heatmap is very useful for identifying correlations

# %% [markdown]
# Cars with bigger engines and higher horsepower tend to have higher prices, and vice versa.

# %% [markdown]
# Thank You

# %% [markdown]
# Converting CSV to Excel

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/250.9 kB 1.4 MB/s eta 0:00:01
#    --------- ----------------------------- 61.4/250.9 kB 825.8 kB/s eta 0:00:01
#    -------------- ------------------------ 92.2/250.9 kB 871.5 kB/s eta 0:00:01
#    ------------------------ --------------- 153.6/250.9 kB 1.0 MB/s eta 0:00:01
#    -------------------------------- ------- 204.8/250.9 kB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.0 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 24.1.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv("updated_df.csv") 
df.to_excel("updated_df.xlsx", index=False)

# %% [markdown]
# Thank you
